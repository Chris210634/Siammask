# %%
ll=[]
for epoch in range(1,21):
    f = open("/usr4/alg504/cliao25/siammask/experiments/siammask_base/tacking_test/test_e{}.txt".format(epoch))
    s = f.read()
    ii = int(s[s.find("Total Lost:")+len("Total Lost:")+1:].split('\n')[0])
    ll.append(ii)

# %%
ll
# Out:
# [104,
#  111,
#  114,
#  105,
#  100,
#  93,
#  86,
#  87,
#  92,
#  101,
#  91,
#  92,
#  100,
#  103,
#  111,
#  127,
#  138,
#  129,
#  133,
#  125]

# %%
import matplotlib.pyplot as plt
plt.plot(ll)
plt.show()
